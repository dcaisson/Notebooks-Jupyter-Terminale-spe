# %% [markdown]
# ## Devoir de Noël (exercice 2, question 3. (b))

# %%
def seuil(E):
    u = 0.5
    n = 0
    while 1 - u >= E:
        u = 4 * u / (1 + 3 * u)
        n = n + 1
    return n

# %%
seuil(10 ** (-4))
# Out:
# 7
